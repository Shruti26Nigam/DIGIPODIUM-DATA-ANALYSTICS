# %%
import pandas as pd
import numpy as np
import seaborn as sns #to add visual or graphic

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
print(df.columns.tolist())
# Out:
# ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']

# %%
df['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
titanic = df[['survived','pclass','sex','age','sibsp','parch','fare','embark_town','alone']].copy()

# %%
titanic.isnull().sum().plot(kind='pie',figsize=(8,3), autopct='%f%%')
# Out:
# <Axes: >

# %% [markdown]
# fix missing value
#  numeric: mean
#  categorical: mode

# %%
avg_age = round(titanic['age'].mean())
print(f'Average age: {avg_age: .1f}')
# Out:
# Average age:  30.0

# %%
titanic['age'].fillna(avg_age,inplace=True)

# %%
# most frequent value in embark_town column
titanic['embark_town'].value_counts().idxmax()
# Out:
# 'Southampton'

# %%
most_freq_embark_town = titanic['embark_town'].value_count().idxmax()
titanic ['embark_town'].fillna(most_freq_town, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 most_freq_embark_town = titanic['embark_town'].value_count().idxmax()
#       2 titanic ['embark_town'].fillna(most_freq_town, inplace=True)
#
# File c:\Users\Admin\miniconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
titanic['survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
titanic.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embark_town    2
# alone          0
# dtype: int64

# %%
# only numerical column free titanic dataframe
df.select_dtypes(include=np.number)
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3  30.0      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
#textual columns from titanic dataframe 
titanic.select_dtypes(include=object)
# Out:
#         sex  embark_town
# 0      male  Southampton
# 1    female    Cherbourg
# 2    female  Southampton
# 3    female  Southampton
# 4      male  Southampton
# ..      ...          ...
# 886    male  Southampton
# 887  female  Southampton
# 888  female  Southampton
# 889    male    Cherbourg
# 890    male   Queenstown
#
# [891 rows x 2 columns]

# %%
# boolean columns from titanic dataframe 
titanic.select_dtypes(include=bool)
# Out:
#      alone
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# ..     ...
# 886   True
# 887   True
# 888  False
# 889   True
# 890   True
#
# [891 rows x 1 columns]

# %% [markdown]
# describing data in terms of mean median mode standard deviation min max,etc

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.758889    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002570    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   30.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.describe(include=[object,bool])
# Out:
#          sex  embark_town alone
# count    891          889   891
# unique     2            3     2
# top     male  Southampton  True
# freq     577          644   537

# %%
# groupby pclass and count total survived
titanic.groupby(['pclass','survived'], as_index=False)['survived'].count() #dataframe
# Out:
#    pclass  survived
# 0       1        80
# 1       1       136
# 2       2        97
# 3       2        87
# 4       3       372
# 5       3       119

# %%
#groupby sex and count total survived
titanic.groupby(['sex','survived'], as_index=False)['survived'].count()
# Out:
#       sex  survived
# 0  female        81
# 1  female       233
# 2    male       468
# 3    male       109

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
titanic.sort_values(by='age', ascending= False)
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare  embark_town  \
# 630         1       1    male  80.00      0      0  30.0000  Southampton
# 851         0       3    male  74.00      0      0   7.7750  Southampton
# 96          0       1    male  71.00      0      0  34.6542    Cherbourg
# 493         0       1    male  71.00      0      0  49.5042    Cherbourg
# 116         0       3    male  70.50      0      0   7.7500   Queenstown
# ..        ...     ...     ...    ...    ...    ...      ...          ...
# 831         1       2    male   0.83      1      1  18.7500  Southampton
# 469         1       3  female   0.75      2      1  19.2583    Cherbourg
# 644         1       3  female   0.75      2      1  19.2583    Cherbourg
# 755         1       2    male   0.67      1      1  14.5000  Southampton
# 803         1       3    male   0.42      0      1   8.5167    Cherbourg
#
#      alone
# 630   True
# 851   True
# 96    True
# 493   True
# 116   True
# ..     ...
# ...
